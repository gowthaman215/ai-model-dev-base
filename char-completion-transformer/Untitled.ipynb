# %%
simple-transformer status
# Out:
#   Cell In[1], line 1
#     simple-transformer status
#                        ^
# SyntaxError: invalid syntax

# %%
# !simple-transformer status
# Out:
# Project: /workspace/ai-model-dev/simple-transformer
# Data files:
#   data/corpus.txt (385869 bytes)
# Current checkpoint:
# -rw-r--r-- 1 1032874684 1032800513 3.2M Aug 22 07:30 out/ckpt.pt
# Current training manifest:
# data/corpus.txt
# Archived runs: 0

# %%
print "hello world"
# Out:
#   Cell In[4], line 1
#     print "hello world"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("hello world")
# Out:
# hello world
